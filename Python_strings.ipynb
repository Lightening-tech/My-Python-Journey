# %%
a = "Hello world!"
print(a.upper())
# Out:
# HELLO WORLD!

# %%
a = "Hello, world!"
print(a.lower())
# Out:
# hello, world!

# %%
a = "     Hello, world!"
print(a.strip())  #returns
# Out:
# Hello, world!

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
a = "Hello, World!"
b = a.split(",")
print(b)
# Out:
# ['Hello', ' World!']

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World
